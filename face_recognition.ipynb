# %% [markdown]
# <a href="https://colab.research.google.com/github/dlguswn3659/big_pie/blob/master/face_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pandas as pd
import math
import os
import sys
import shutil
import urllib.request
import zipfile
import smtplib
from matplotlib import pyplot
from matplotlib.image import imread
from datetime import datetime
from email.message import EmailMessage

# %%
import cv2
from google.colab.patches import cv2_imshow

from torchvision.utils import save_image
import torch
import torchvision

import scipy.misc
from PIL import Image

# from google.colab import files
# uploaded = files.upload()

# import zipfile
# import io
# zf = zipfile.ZipFile(io.BytesIO(uploaded['KGES.zip']), "r")
# zf.extractall()

face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
# eye_casecade = cv2.CascadeClassifier('../haarcascades/haarcascade_eye.xml')

folder = 'face_recognition/'
folder2 = 'KGES/'

# %%
for i in range(0, 1016):
  filename = folder2 + '0 (' + str(i) + ').jpg'

  img = cv2.imread(filename)
  # cv2_imshow(img)
  # print(i)

  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  faces = face_cascade.detectMultiScale(gray, 1.3,5)
  for (x,y,w,h) in faces:
      # cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0),2)
      # cropped = img[y - int(h/4):y + h + int(h/4), x - int(w/4):x + w + int(w/4)]
      cropped = img[y:y+h, x:x+w, :].astype('uint8')
      # roi_gray = gray[y:y+h, x:x+w]
      # roi_color = img[y:y+h, x:x+w]
      # eyes = eye_casecade.detectMultiScale(roi_gray)
      # for (ex, ey, ew, eh) in eyes:
          # cv2.rectangle(roi_color, (ex,ey), (ex+ew, ey+eh),(0,255,0),2)

  # print(cropped)

  # cropped.to_csv('dami_face_1.jpg')
  # files.download('dami_face_1.jpg')
  # print(type(cropped))

  # cropped = cropped.numpy() # TypeError: tensor or list of tensors expected, got <class 'numpy.ndarray'>
  # save_image()
  # save_image(cropped, 'dami_face_1.jpg')
  save_filename = folder + '0 (' + str(i) + ').jpg'
  im = Image.fromarray(cropped).convert('RGB')
  # print(im)
  # im = (np.float32(im), cv2.COLOR_BGR2RGB)
  # im = cv2.cvtColor(cv2.UMat(im), cv2.COLOR_BGR2RGB)
  # print('///////////////')
  # print(im)
  cropped = cv2.cvtColor(cropped, cv2.COLOR_RGB2BGR)
  im = Image.fromarray(cropped).convert('RGB')
  im.save(save_filename)
  # scipy.misc.toimage(cropped, cmin=0.0, cmax=...).save('dami_face_1.jpg')
  # cv2.imshow('Image view', cropped)
  # cv2_imshow(cv2.cvtColor(cropped, cv2.COLOR_RGB2BGR))
  cv2.waitKey(0)
  cv2.destroyAllWindows()

# %%
for i in range(0, 974):
  filename = folder2 + '1 (' + str(i) + ').jpg'

  img = cv2.imread(filename)
  # cv2_imshow(img)
  # print(i)

  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  faces = face_cascade.detectMultiScale(gray, 1.3,5)
  for (x,y,w,h) in faces:
      cropped = img[y:y+h, x:x+w, :].astype('uint8')

  save_filename = folder + '1 (' + str(i) + ').jpg'
  im = Image.fromarray(cropped).convert('RGB')

  cropped = cv2.cvtColor(cropped, cv2.COLOR_RGB2BGR)
  im = Image.fromarray(cropped).convert('RGB')
  im.save(save_filename)
  
  cv2.waitKey(0)
  cv2.destroyAllWindows()

# %%
for i in range(0, 526):
  filename = folder2 + '3 (' + str(i) + ').jpg'

  img = cv2.imread(filename)
  # cv2_imshow(img)
  # print(i)

  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  faces = face_cascade.detectMultiScale(gray, 1.3,5)
  for (x,y,w,h) in faces:
      cropped = img[y:y+h, x:x+w, :].astype('uint8')

  save_filename = folder + '3 (' + str(i) + ').jpg'
  im = Image.fromarray(cropped).convert('RGB')

  cropped = cv2.cvtColor(cropped, cv2.COLOR_RGB2BGR)
  im = Image.fromarray(cropped).convert('RGB')
  im.save(save_filename)
  
  cv2.waitKey(0)
  cv2.destroyAllWindows()

# %%
for i in range(0, 1000):
  if i == 0 or i == 998:
    filename = folder2 + '2 (' + str(i) + ').jpeg'
  elif i == 1 or i == 2 or i == 3 or i == 994 or i == 995:
    filename = folder2 + '2 (' + str(i) + ').png'
  else:
    filename = folder2 + '2 (' + str(i) + ').jpg'

  img = cv2.imread(filename)
  # cv2_imshow(img)
  # print(i)

  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  faces = face_cascade.detectMultiScale(gray, 1.3,5)
  for (x,y,w,h) in faces:
      cropped = img[y:y+h, x:x+w, :].astype('uint8')

  if i == 0 or i == 998:
    save_filename = folder + '2 (' + str(i) + ').jpeg'
  elif i == 1 or i == 2 or i == 3 or i == 994 or i == 995:
    save_filename = folder + '2 (' + str(i) + ').png'
  else:
    save_filename = folder + '2 (' + str(i) + ').jpg'

  im = Image.fromarray(cropped).convert('RGB')

  cropped = cv2.cvtColor(cropped, cv2.COLOR_RGB2BGR)
  im = Image.fromarray(cropped).convert('RGB')
  im.save(save_filename)
  
  cv2.waitKey(0)
  cv2.destroyAllWindows()

# %%
# !zip -r /content/file.zip /content/face_recognition
# Out:
#   adding: content/face_recognition/ (stored 0%)
#   adding: content/face_recognition/0 (624).jpg (deflated 1%)
#   adding: content/face_recognition/1 (547).jpg (deflated 10%)
#   adding: content/face_recognition/2 (698).jpg (deflated 3%)
#   adding: content/face_recognition/0 (957).jpg (deflated 8%)
#   adding: content/face_recognition/3 (228).jpg (deflated 6%)
#   adding: content/face_recognition/0 (581).jpg (deflated 4%)
#   adding: content/face_recognition/1 (74).jpg (deflated 3%)
#   adding: content/face_recognition/0 (80).jpg (deflated 7%)
#   adding: content/face_recognition/0 (735).jpg (deflated 1%)
#   adding: content/face_recognition/0 (98).jpg (deflated 9%)
#   adding: content/face_recognition/0 (291).jpg (deflated 2%)
#   adding: content/face_recognition/1 (709).jpg (deflated 4%)
#   adding: content/face_recognition/0 (848).jpg (deflated 3%)
#   adding: content/face_recognition/2 (617).jpg (deflated 8%)
#   adding: content/face_recognition/3 (173).jpg (deflated 3%)
# ...

# %%
from google.colab import files
files.download("/content/file.zip")

# %%
# # load dogs vs cats dataset, reshape and save to a new file
# from os import listdir
# from numpy import asarray
# from numpy import save
# from keras.preprocessing.image import load_img
# from keras.preprocessing.image import img_to_array
# # define location of dataset
# folder = 'train/train/'
# photos, labels = list(), list()
# # enumerate files in the directory
# for file in listdir(folder):
# 	# determine class
# 	output = 0.0                #안지영(0 ~ 1015) total : 1016장
# 	if file.startswith('1'):    #김고은(0 ~ 973) total : 974장
# 		output = 1.0
#   elif file.startswith('2'):  #박소담(0 ~ 999) total : 1000장
# 		output = 2.0
#   elif file.startswith('3'):  #김다미(0 ~ 525) total : 526장
# 		output = 3.0
# 	# load image
# 	photo = load_img(folder + file, target_size=(200, 200))
# 	# convert to numpy array
# 	photo = img_to_array(photo)
# 	# store
# 	photos.append(photo)
# 	labels.append(output)
# # convert to a numpy arrays
# photos = asarray(photos)
# labels = asarray(labels)
# print(photos.shape, labels.shape)
# # save the reshaped photos
# save('kges_photos.npy', photos)
# save('kges_labels.npy', labels)
